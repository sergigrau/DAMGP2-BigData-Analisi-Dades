# %% [markdown]
# ## Relació entre variables: causalitat, correlació i regressió

# %% [markdown]
# ### Jesuïtes El Clot  DAM, Global Project Big Data
# sergi.grau@fje.edu

# %% [markdown]
# ### Relació entre variables
#
# Quan estudiem conjuntament dues variables o més que no són independents, la relació entre elles pot ser funcional (per exemple, relació matemàtica exacta entre dues variables, espai recorregut per un vehicle que circula a velocitat constant i el temps emprat a recórrer-lo) o estadística (per exemple, no hi ha una expressió matemàtica exacta que relacioni ambdues variables, hi ha una relació aproximada entre les dues variables, increment de les vendes de llibres en funció de la quantitat gastada en publicitat). En aquest últim cas ens interessa estudiar el grau de dependència existent entre ambdues variables. Ho farem mitjançant l’anàlisi de correlació i, finalment, desenvoluparem un model matemàtic per a estimar el valor d’una variable basant-nos en el valor d’una altra, de la qual cosa en direm anàlisi de regressió.

# %% [markdown]
# ### L’anàlisi de regressió i  correlació
#
# L’anàlisi de regressió no es pot interpretar com un procediment per a establir una relació causa-efecte o causalitat entre variables. La regressió només pot indicar com estan associades les variables entre elles i ens permet construir un model per a explicar-ne la relació.
#
# **La correlació indica el grau de la relació entre dues variables sense suposar que una alteració en l’una causi un canvi en l’altra variable**

# %% [markdown]
# ### Regressió simple
#
# L’objectiu principal de l’anàlisi de regressió és **explicar el comportament d’una variable dependent Y (endògena o explicada) a partir d’una variable independent o diverses (exògenes o explicatives)**. El tipus més senzill de regressió és la regressió simple.
#
# La regressió lineal simple estima una equació lineal que descriu la relació, mentre que la correlació mesura la força de la relació lineal
#
# A part dels models lineals, podem establir altres models de regressió no lineals.

# %% [markdown]
# ### Regressió múltiple
#
# L’anàlisi de regressió on intervenen dues variables independents o més en diem anàlisi de regressió múltiple, en la qual una variable és explicada per l’acció simultània d’altres variables.

# %% [markdown]
# ![Captura%20de%20pantalla%202022-11-08%20a%20les%2010.32.27.png](attachment:Captura%20de%20pantalla%202022-11-08%20a%20les%2010.32.27.png)

# %% [markdown]
# ### Covariança
#
# La covariància mostral entre dues variables X i Y ens permet mesurar aquestes relacions positives i negatives entre les variables X i Y

# %% [markdown]
# ![Captura%20de%20pantalla%202022-11-08%20a%20les%2010.35.10.png](attachment:Captura%20de%20pantalla%202022-11-08%20a%20les%2010.35.10.png)

# %% [markdown]
# ### Anàlisi de la correlació
#
# L’anàlisi de correlació mesura el grau de relació entre les variables.
#
# L’anàlisi de correlació simple mesura la relació entre només una variable independent (X) i la variable dependent (Y)
#
# La correlació simple determina la quantitat de variació conjunta que presenten dues variables aleatòries d’una distribució bidimensional. En concret, quantifica la dependència lineal, i en aquest cas hi haurà correlació lineal
#
# El coeficient de correlació lineal es diu **coeficient de correlació de Pearson designat r**, el valor del qual oscil·la entre –1 i +1. La seva expressió és el quocient entre la covariància mostral entre les variables i el producte de les seves respectives desviacions típiques:

# %% [markdown]
# ![Captura%20de%20pantalla%202022-11-08%20a%20les%2010.36.49.png](attachment:Captura%20de%20pantalla%202022-11-08%20a%20les%2010.36.49.png)

# %% [markdown]
# El valor de r s’aproxima a +1 quan la correlació tendeix a ser lineal directa (majors valors de X signifiquen majors valors de Y), i s’aproxima a -1 quan la correlació tendeix a ser lineal inversa.
#
# La relació és feble si 0 <= |r| <? 0,5; forta si 0,8 <= |r| <=1, i moderada si té un altre valor.

# %% [markdown]
# ## Exemple

# %% [markdown]
# ![Captura%20de%20pantalla%202022-11-08%20a%20les%2010.39.43.png](attachment:Captura%20de%20pantalla%202022-11-08%20a%20les%2010.39.43.png)
#
#
# Per a determinar si hi ha correlació lineal entre les dues variables, calculem el coeficient de correlació r.
# Fem els càlculs necessaris per a determinar els valors de les variàncies, les desviacions típiques mostrals i la covariància mostral.

# %% [markdown]
# ![Captura%20de%20pantalla%202022-11-08%20a%20les%2010.40.15.png](attachment:Captura%20de%20pantalla%202022-11-08%20a%20les%2010.40.15.png)

# %% [markdown]
# ![Captura%20de%20pantalla%202022-11-08%20a%20les%2010.40.39.png](attachment:Captura%20de%20pantalla%202022-11-08%20a%20les%2010.40.39.png)
#
# Com que el valor del coeficient de correlació lineal és pròxim a 1, es pot afir- mar que hi ha una correlació lineal positiva entre les valoracions obtingudes d’atenció a l’usuari i les valoracions del funcionament global del centre

# %%
import pandas as pd

origen = [[ 2, 2], [ 4, 10], [ 6, 5],  [ 8, 4],  [ 10, 1]]
df = pd.DataFrame(origen, columns=[ "funcionament", "atencio"])
df
# Out:
#    funcionament  atencio
# 0             2        2
# 1             4       10
# 2             6        5
# 3             8        4
# 4            10        1

# %%
#desviació estandar
df.std()
# Out:
# funcionament    3.162278
# atencio         3.507136
# dtype: float64

# %%
#covariança
df.cov()
# Out:
#               funcionament  atencio
# funcionament          10.0     -4.0
# atencio               -4.0     12.3

# %%
r = df.corr()
r
# Out:
#               funcionament   atencio
# funcionament      1.000000 -0.360668
# atencio          -0.360668  1.000000

# %% [markdown]
# ### Models de regressió lineal simple
#
# La recta que millor s’ajusti al núvol de punts s’anomena **recta de regressió**.
# Una recta queda ben determinada si el valor del seu pendent (b) i de l’ordenada en l’origen (a) són conegudes. D’aquesta manera l’equació de la recta és donada per:
#
# ![Captura%20de%20pantalla%202022-11-08%20a%20les%2010.43.24.png](attachment:Captura%20de%20pantalla%202022-11-08%20a%20les%2010.43.24.png)
#
#
# Per cada recta considerada, hi ha una col·lecció diferent de residus. Cal buscar la recta que minimitzi la suma dels quadrats dels residus. Aquest és el mètode dels mínims quadrats, un procediment per a trobar l’equació de regressió que consisteix a buscar els valors dels coeficients a i b de manera que la suma dels quadrats dels residus sigui mínima, i així obtenim **la recta de regressió per mínims quadrats**
#
# ![Captura%20de%20pantalla%202022-11-08%20a%20les%2010.44.06.png](attachment:Captura%20de%20pantalla%202022-11-08%20a%20les%2010.44.06.png)
#
#
# Escriurem la recta de regressió de la manera següent:
#
# ![Captura%20de%20pantalla%202022-11-08%20a%20les%2010.44.40.png](attachment:Captura%20de%20pantalla%202022-11-08%20a%20les%2010.44.40.png)
#
# ![Captura%20de%20pantalla%202022-11-08%20a%20les%2010.45.04.png](attachment:Captura%20de%20pantalla%202022-11-08%20a%20les%2010.45.04.png)
#
# Perquè la línia estimada de regressió s’ajusti bé amb les dades, les diferències entre els valors observats i els valors estimats d’atenció a l’usuari han de ser petits.
#
# ![Captura%20de%20pantalla%202022-11-08%20a%20les%2010.45.36.png](attachment:Captura%20de%20pantalla%202022-11-08%20a%20les%2010.45.36.png)

# %% [markdown]
# ### Interpretació
#
# Interpretació de l’ordenada en l’origen, B0: Aquest coeficient representa l’estimació del valor de Y quan X és igual a zero. No sempre té una interpretació pràctica. Perquè sigui possible, és necessari que realment sigui possible que X prengui el valor x = 0, i es tinguin prou observacions properes al valor x = 0.
#
# Interpretació del pendent de la recta B1 : Aquest coeficient representa l’estimació de l’increment que experimenta la variable Y quan X augmenta en una unitat. Aquest coeficient ens informa de com estan relacionades les dues variables en quina quantitat varien els valors de Y quan varien els valors de la X en una unitat.

# %% [markdown]
# ### La qualitat o bondat de l'ajust
#
# Una vegada calculada la recta de regressió per mínims quadrats hem d’analit- zar si aquest ajust al model és prou bo. Si mirem si en el diagrama de dispersió els punts experimentals queden molt a prop de la recta de regressió obtinguda, podem tenir una idea de si la recta s’ajusta o no a les dades, però ens fa falta un valor numèric que ens ajudi a necessitar-ho
#
# La mesura de bondat d’ajust per a una equació de regressió és el **coeficient de determinació R2**
#
# ![Captura%20de%20pantalla%202022-11-08%20a%20les%2010.50.35.png](attachment:Captura%20de%20pantalla%202022-11-08%20a%20les%2010.50.35.png)
#
#
# La variància explicada per la recta de regressió és la variància dels valors estimats.
#
# Variància total de Y = vvariància explicada per la regressió + variància no explicada (residual o dels errors) , o sigui SSTotal = SSRegressió + SSError
#
# ![Captura%20de%20pantalla%202022-11-08%20a%20les%2010.51.10.png](attachment:Captura%20de%20pantalla%202022-11-08%20a%20les%2010.51.10.png)
#
# Els valors del coeficient de determinació estan compresos entre zero i u: 0 <= R2 <= 1
#
# R2 =1 quan l’ajust és perfecte, és a dir, tots els punts són sobre la recta de
# regressió.
#
# R2 = 0 mostra la inexistència de relació entre les variables X i Y.

# %%
import matplotlib.pyplot as plt
import numpy as np
ax= df.plot.scatter(x='atencio',y='funcionament')

# %%
d = np.polyfit(df['atencio'],df['funcionament'],1)
f = np.poly1d(d)

df.insert(2,'reg',f(df['atencio']))
ax= df.plot.scatter(x='atencio',y='funcionament')
df.plot(x='atencio',y='reg',color='Red',legend=False,ax=ax)
# Out:
# <AxesSubplot:xlabel='atencio', ylabel='funcionament'>

# %%
from sklearn.metrics import r2_score
round(r2_score(df.funcionament, df.reg),2)
# Out:
# 0.13

# %% [markdown]
# ### La relació entre R2 i R
#
# És molt important tenir clara la diferència entre el coeficient de correlació i el coeficient de determinació:
#
# R2 mesura la proporció de variació de la variable dependent explicada per la variable independent.
#
# r2 és el coeficient de correlació, mesura el grau d’associació lineal entre les dues variables.
#
# No obstant això, en la regressió lineal simple tenim que R2 = r2

# %% [markdown]
# ### Predicció
#
# La predicció constitueix una de les aplicacions més interessants de la tècnica de regressió. La predicció consisteix a determinar a partir del model estimat el valor que pren la variable endògena per a un valor determinat de l’exògena. La fiabilitat d’aquesta predicció serà tant més gran, en principi, com millor sigui l’ajust (és a dir, com més gran sigui R2), en el supòsit que hi hagi relació causal entre la variable endògena i la variable exògena.
